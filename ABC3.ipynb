# %% [markdown]
# <a href="https://colab.research.google.com/github/Swastik200/30DaysOfDSA/blob/main/ABC3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyMetaheuristic
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.linear_model import LinearRegression
from pyMetaheuristic.algorithm import artificial_bee_colony_optimization
from pyMetaheuristic.utils import graphs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/CMAPSS.zip" "/content"
# !unzip CMAPSS.zip
# Out:
# Archive:  CMAPSS.zip
#   inflating: CMAPSS/readme.txt
#   inflating: CMAPSS/RUL_FD001.txt
#   inflating: CMAPSS/RUL_FD002.txt
#   inflating: CMAPSS/RUL_FD003.txt
#   inflating: CMAPSS/RUL_FD004.txt
#   inflating: CMAPSS/test_FD001.txt
#   inflating: CMAPSS/test_FD002.txt
#   inflating: CMAPSS/test_FD003.txt
#   inflating: CMAPSS/test_FD004.txt
#   inflating: CMAPSS/train_FD001.txt
#   inflating: CMAPSS/train_FD002.txt
#   inflating: CMAPSS/train_FD003.txt
#   inflating: CMAPSS/train_FD004.txt
#   inflating: CMAPSS/x.txt

# %%
index_names = ['unit_number', 'time_cycles']
setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names = ['sensor_{}'.format(i) for i in range(1,22)]
col_names = index_names + setting_names + sensor_names

# %%
path = '/content/CMAPSS/'
df_train = pd.read_csv(path+'train_FD003.txt',sep='\s+',header=None,index_col=False,names=col_names) #\s表示以空白為間隔
df_test = pd.read_csv(path+'test_FD003.txt',sep='\s+',header=None,index_col=False,names=col_names)
y_test = pd.read_csv(path+'RUL_FD003.txt',sep='\s+',header=None,index_col=False,names=['RUL'])
y_test.shape
# Out:
# (100, 1)

# %%
train = df_train.copy()
test = df_test.copy()
display(train)
display(test)
# Out:
#        unit_number  time_cycles  setting_1  setting_2  setting_3  sensor_1  \
# 0                1            1    -0.0005     0.0004      100.0    518.67
# 1                1            2     0.0008    -0.0003      100.0    518.67
# 2                1            3    -0.0014    -0.0002      100.0    518.67
# 3                1            4    -0.0020     0.0001      100.0    518.67
# 4                1            5     0.0016     0.0000      100.0    518.67
# ...            ...          ...        ...        ...        ...       ...
# 24715          100          148    -0.0016    -0.0003      100.0    518.67
# 24716          100          149     0.0034    -0.0003      100.0    518.67
# 24717          100          150    -0.0016     0.0004      100.0    518.67
# 24718          100          151    -0.0023     0.0004      100.0    518.67
# 24719          100          152     0.0000     0.0003      100.0    518.67
#
# ...

# %%
def regression_model(X):
    # Define your regression model here
    model = artificial_bee_colony_optimization()
    model.fit(X_train, y_train)
    return model.predict(X)

# %%
# Calculate 'RUL' column based on 'time_cycles' and 'unit_number' columns
max_cycles = df_train.groupby('unit_number')['time_cycles'].max()
df_train['RUL'] = df_train.apply(lambda row: max_cycles[row['unit_number']] - row['time_cycles'], axis=1)
# Calculate 'RUL' column based on 'time_cycles' and 'unit_number' columns
max_cycles = df_test.groupby('unit_number')['time_cycles'].max()
df_test['RUL'] = df_test.apply(lambda row: max_cycles[row['unit_number']] - row['time_cycles'], axis=1)

# %%
X_train = df_train.drop(columns=['RUL'])
y_train = df_train['RUL']
X_test = df_test.drop(columns=['RUL'])
y_test = df_test['RUL']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
def target_function(variables_values):
    # Train the regression model
    model = LinearRegression()
    model.fit(X_train_scaled, y_train)
    # Predict using the trained model
    predictions = model.predict(X_train_scaled)
    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y_train, predictions))
    return rmse

# %%
parameters = {
    'food_sources': 20,
    'min_values': [-5] * len(X_train.columns),  # Adjust according to your feature space
    'max_values': [5] * len(X_train.columns),  # Adjust according to your feature space
    'iterations': 10,
    'employed_bees': 20,
    'outlookers_bees': 20,
    'limit': 20,
    'verbose': True,
    'start_init': None,
    'target_value': None
}

# %%
def target_function(variables_values):
    # Train the regression model
    model = LinearRegression()
    model.fit(X_train, y_train)
    # Predict using the trained model
    predictions = model.predict(X_train)
    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y_train, predictions))
    return rmse

# %%
abco_result = artificial_bee_colony_optimization(target_function=target_function, **parameters)
# Out:
# Iteration =  1  f(x) =  60.90042476008926
# Iteration =  2  f(x) =  60.90042476008926
# Iteration =  3  f(x) =  60.90042476008926
# Iteration =  4  f(x) =  60.90042476008926
# Iteration =  5  f(x) =  60.90042476008926
# Iteration =  6  f(x) =  60.90042476008926
# Iteration =  7  f(x) =  60.90042476008926
# Iteration =  8  f(x) =  60.90042476008926
# Iteration =  9  f(x) =  60.90042476008926
# Iteration =  10  f(x) =  60.90042476008926

# %%
# Select the first 100 samples from X_test_scaled and their corresponding target values
X_test_scaled_subset = X_test_scaled[:100]
y_test_subset = y_test[:100]

# %%
optimized_model = LinearRegression().fit(X_test_scaled_subset, y_test_subset)

# %%
rmse_test = np.sqrt(mean_squared_error(y_test_subset, optimized_model.predict(X_test_scaled_subset)))
r2_test = r2_score(y_test_subset, optimized_model.predict(X_test_scaled_subset))
mae_test = mean_absolute_error(y_test_subset, optimized_model.predict(X_test_scaled_subset))

# %%
print('RMSE (Test):', rmse_test)
print('R2 Score (Test):', r2_test)
print('MAE (Test):', mae_test)
# Out:
# RMSE (Test): 6.33619288510316e-14
# R2 Score (Test): 1.0
# MAE (Test): 4.916955731459893e-14
