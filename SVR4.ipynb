# %% [markdown]
# <a href="https://colab.research.google.com/github/Swastik200/30DaysOfDSA/blob/main/SVR4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
from sklearn.svm import SVR

# %%
# !cp "/content/drive/MyDrive/CMAPSS.zip" "/content"
# !unzip CMAPSS.zip
# Out:
# Archive:  CMAPSS.zip
#   inflating: CMAPSS/readme.txt
#   inflating: CMAPSS/RUL_FD001.txt
#   inflating: CMAPSS/RUL_FD002.txt
#   inflating: CMAPSS/RUL_FD003.txt
#   inflating: CMAPSS/RUL_FD004.txt
#   inflating: CMAPSS/test_FD001.txt
#   inflating: CMAPSS/test_FD002.txt
#   inflating: CMAPSS/test_FD003.txt
#   inflating: CMAPSS/test_FD004.txt
#   inflating: CMAPSS/train_FD001.txt
#   inflating: CMAPSS/train_FD002.txt
#   inflating: CMAPSS/train_FD003.txt
#   inflating: CMAPSS/train_FD004.txt
#   inflating: CMAPSS/x.txt

# %%
index_names = ['unit_number', 'time_cycles']
setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names = ['sensor_{}'.format(i) for i in range(1,22)]
col_names = index_names + setting_names + sensor_names

# %%
path = '/content/CMAPSS/'
df_train = pd.read_csv(path+'train_FD004.txt',sep='\s+',header=None,index_col=False,names=col_names) #\s表示以空白為間隔
df_test = pd.read_csv(path+'test_FD004.txt',sep='\s+',header=None,index_col=False,names=col_names)
y_test = pd.read_csv(path+'RUL_FD004.txt',sep='\s+',header=None,index_col=False,names=['RUL'])
y_test.shape
# Out:
# (248, 1)

# %%
train = df_train.copy()
test = df_test.copy()
display(train)
display(test)
# Out:
#        unit_number  time_cycles  setting_1  setting_2  setting_3  sensor_1  \
# 0                1            1    42.0049     0.8400      100.0    445.00
# 1                1            2    20.0020     0.7002      100.0    491.19
# 2                1            3    42.0038     0.8409      100.0    445.00
# 3                1            4    42.0000     0.8400      100.0    445.00
# 4                1            5    25.0063     0.6207       60.0    462.54
# ...            ...          ...        ...        ...        ...       ...
# 61244          249          251     9.9998     0.2500      100.0    489.05
# 61245          249          252     0.0028     0.0015      100.0    518.67
# 61246          249          253     0.0029     0.0000      100.0    518.67
# 61247          249          254    35.0046     0.8400      100.0    449.44
# 61248          249          255    42.0030     0.8400      100.0    445.00
#
#        sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  \
# 0        549.68   1343.43   1112.93      3.91  ...     129.78    2387.99
# 1        606.07   1477.61   1237.50      9.35  ...     312.59    2387.73
# 2        548.95   1343.12   1117.05      3.91  ...     129.62    2387.97
# 3        548.70   1341.24   1118.03      3.91  ...     129.80    2388.02
# 4        536.10   1255.23   1033.59      7.05  ...     164.11    2028.08
# ...         ...       ...       ...       ...  ...        ...        ...
# 61244    605.33   1516.36   1315.28     10.52  ...     380.16    2388.73
# 61245    643.42   1598.92   1426.77     14.62  ...     535.02    2388.46
# 61246    643.68   1607.72   1430.56     14.62  ...     535.41    2388.48
# 61247    555.77   1381.29   1148.18      5.48  ...     187.92    2388.83
# 61248    549.85   1369.75   1147.45      3.91  ...     134.32    2388.66
#
#        sensor_14  sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  \
# 0        8074.83     9.3335       0.02        330       2212     100.00
# 1        8046.13     9.1913       0.02        361       2324     100.00
# 2        8066.62     9.4007       0.02        329       2212     100.00
# 3        8076.05     9.3369       0.02        328       2212     100.00
# 4        7865.80    10.8366       0.02        305       1915      84.93
# ...          ...        ...        ...        ...        ...        ...
# 61244    8185.69     8.4541       0.03        372       2319     100.00
# 61245    8185.47     8.2221       0.03        396       2388     100.00
# 61246    8193.94     8.2525       0.03        395       2388     100.00
# 61247    8125.64     9.0515       0.02        337       2223     100.00
# 61248    8144.33     9.1207       0.02        333       2212     100.00
#
#        sensor_20  sensor_21
# 0          10.62     6.3670
# 1          24.37    14.6552
# 2          10.48     6.4213
# 3          10.54     6.4176
# 4          14.03     8.6754
# ...          ...        ...
# 61244      29.11    17.5234
# 61245      39.38    23.7151
# 61246      39.78    23.8270
# 61247      15.26     9.0774
# 61248      10.66     6.4341
#
# [61249 rows x 26 columns]
#        unit_number  time_cycles  setting_1  setting_2  setting_3  sensor_1  \
# 0                1            1    20.0072     0.7000      100.0    491.19
# 1                1            2    24.9984     0.6200       60.0    462.54
# 2                1            3    42.0000     0.8420      100.0    445.00
# 3                1            4    42.0035     0.8402      100.0    445.00
# 4                1            5    35.0079     0.8400      100.0    449.44
# ...            ...          ...        ...        ...        ...       ...
# 41209          248          277    41.9991     0.8401      100.0    445.00
# 41210          248          278    20.0026     0.7005      100.0    491.19
# 41211          248          279    34.9988     0.8413      100.0    449.44
# 41212          248          280    20.0027     0.7000      100.0    491.19
# 41213          248          281    35.0075     0.8402      100.0    449.44
#
#        sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  \
# 0        606.67   1481.04   1227.81      9.35  ...     313.03    2387.78
# 1        536.22   1256.17   1031.48      7.05  ...     163.61    2028.09
# 2        549.23   1340.13   1105.88      3.91  ...     129.98    2387.95
# 3        549.19   1339.70   1107.26      3.91  ...     129.48    2387.90
# 4        555.10   1353.04   1117.80      5.48  ...     181.82    2387.87
# ...         ...       ...       ...       ...  ...        ...        ...
# 41209    550.30   1364.40   1129.17      3.91  ...     130.87    2388.50
# 41210    608.00   1494.75   1260.88      9.35  ...     314.51    2388.33
# 41211    555.92   1370.65   1130.97      5.48  ...     182.76    2388.64
# 41212    608.19   1489.11   1256.25      9.35  ...     314.17    2388.37
# 41213    556.40   1378.58   1140.70      5.48  ...     181.88    2388.59
#
#        sensor_14  sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  \
# 0        8048.98     9.2229       0.02        362       2324     100.00
# 1        7863.46    10.8632       0.02        306       1915      84.93
# 2        8071.13     9.3960       0.02        328       2212     100.00
# 3        8078.89     9.3594       0.02        328       2212     100.00
# 4        8057.83     9.3030       0.02        333       2223     100.00
# ...          ...        ...        ...        ...        ...        ...
# 41209    8112.61     9.4427       0.02        331       2212     100.00
# 41210    8086.83     9.2772       0.02        366       2324     100.00
# 41211    8100.84     9.3982       0.02        336       2223     100.00
# 41212    8085.24     9.2727       0.03        366       2324     100.00
# 41213    8098.17     9.3964       0.02        335       2223     100.00
#
#        sensor_20  sensor_21
# 0          24.31    14.7007
# 1          14.36     8.5748
# 2          10.39     6.4365
# 3          10.56     6.2367
# 4          14.85     8.9326
# ...          ...        ...
# 41209      10.53     6.2620
# 41210      24.33    14.6486
# 41211      14.69     8.8389
# 41212      24.44    14.6887
# 41213      14.72     8.8502
#
# [41214 rows x 26 columns]

# %%
def add_RUL_column(df):
    max_time_cycles = df.groupby(by='unit_number')['time_cycles'].max()
    merged = df.merge( max_time_cycles.to_frame(name='max_time_cycle'), left_on='unit_number',right_index=True)
    merged["RUL"] = merged["max_time_cycle"] - merged['time_cycles']
    merged = merged.drop("max_time_cycle", axis=1)
    return merged
train = add_RUL_column(train)
display(train)
# Out:
#        unit_number  time_cycles  setting_1  setting_2  setting_3  sensor_1  \
# 0                1            1    42.0049     0.8400      100.0    445.00
# 1                1            2    20.0020     0.7002      100.0    491.19
# 2                1            3    42.0038     0.8409      100.0    445.00
# 3                1            4    42.0000     0.8400      100.0    445.00
# 4                1            5    25.0063     0.6207       60.0    462.54
# ...            ...          ...        ...        ...        ...       ...
# 61244          249          251     9.9998     0.2500      100.0    489.05
# 61245          249          252     0.0028     0.0015      100.0    518.67
# 61246          249          253     0.0029     0.0000      100.0    518.67
# 61247          249          254    35.0046     0.8400      100.0    449.44
# 61248          249          255    42.0030     0.8400      100.0    445.00
#
#        sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_13  sensor_14  \
# 0        549.68   1343.43   1112.93      3.91  ...    2387.99    8074.83
# 1        606.07   1477.61   1237.50      9.35  ...    2387.73    8046.13
# 2        548.95   1343.12   1117.05      3.91  ...    2387.97    8066.62
# 3        548.70   1341.24   1118.03      3.91  ...    2388.02    8076.05
# 4        536.10   1255.23   1033.59      7.05  ...    2028.08    7865.80
# ...         ...       ...       ...       ...  ...        ...        ...
# 61244    605.33   1516.36   1315.28     10.52  ...    2388.73    8185.69
# 61245    643.42   1598.92   1426.77     14.62  ...    2388.46    8185.47
# 61246    643.68   1607.72   1430.56     14.62  ...    2388.48    8193.94
# 61247    555.77   1381.29   1148.18      5.48  ...    2388.83    8125.64
# 61248    549.85   1369.75   1147.45      3.91  ...    2388.66    8144.33
#
#        sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  \
# 0         9.3335       0.02        330       2212     100.00      10.62
# 1         9.1913       0.02        361       2324     100.00      24.37
# 2         9.4007       0.02        329       2212     100.00      10.48
# 3         9.3369       0.02        328       2212     100.00      10.54
# 4        10.8366       0.02        305       1915      84.93      14.03
# ...          ...        ...        ...        ...        ...        ...
# 61244     8.4541       0.03        372       2319     100.00      29.11
# 61245     8.2221       0.03        396       2388     100.00      39.38
# 61246     8.2525       0.03        395       2388     100.00      39.78
# 61247     9.0515       0.02        337       2223     100.00      15.26
# 61248     9.1207       0.02        333       2212     100.00      10.66
#
#        sensor_21  RUL
# 0         6.3670  320
# 1        14.6552  319
# 2         6.4213  318
# 3         6.4176  317
# 4         8.6754  316
# ...          ...  ...
# 61244    17.5234    4
# 61245    23.7151    3
# 61246    23.8270    2
# 61247     9.0774    1
# 61248     6.4341    0
#
# [61249 rows x 27 columns]

# %%
maxrul_u = train.groupby('unit_number').max().reset_index()
maxrul_u.head()
# Out:
#    unit_number  time_cycles  setting_1  setting_2  setting_3  sensor_1  \
# 0            1          321    42.0079     0.8420      100.0    518.67
# 1            2          299    42.0079     0.8420      100.0    518.67
# 2            3          307    42.0079     0.8420      100.0    518.67
# 3            4          274    42.0080     0.8419      100.0    518.67
# 4            5          193    42.0072     0.8418      100.0    518.67
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_13  sensor_14  \
# 0    643.50   1603.28   1422.53     14.62  ...    2388.87    8184.95
# 1    643.88   1599.51   1434.23     14.62  ...    2388.37    8143.04
# 2    643.45   1605.04   1425.73     14.62  ...    2388.91    8188.39
# 3    644.07   1605.47   1432.75     14.62  ...    2389.42    8210.13
# 4    643.76   1607.29   1430.47     14.62  ...    2389.46    8187.83
#
#    sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  \
# 0    10.9141       0.03        397       2388      100.0      39.58
# 1    11.0337       0.03        396       2388      100.0      39.15
# 2    10.8552       0.03        396       2388      100.0      39.51
# 3    11.0113       0.03        397       2388      100.0      39.11
# 4    11.0254       0.03        398       2388      100.0      38.96
#
#    sensor_21  RUL
# 0    23.8649  320
# 1    23.4692  298
# 2    23.7657  306
# 3    23.4354  273
# 4    23.4060  192
#
# [5 rows x 27 columns]

# %%
drop_labels1 = ['unit_number','time_cycles','setting_1','setting_2','setting_3','RUL']

X = train.drop(drop_labels1,axis = 1)
Y = train['RUL']

X_train, X_valid, y_train, y_valid= train_test_split(X,Y, test_size=0.3, random_state=42)

# Conserve only the last occurence of each unit to match the length of y_valid
X_test = df_test.groupby('unit_number').last().reset_index().drop(columns=['unit_number','time_cycles','setting_1','setting_2','setting_3'])
y_test = y_test.values.reshape(1,len(y_test))[0]

# %%
X_train.columns
# Out:
# Index(['sensor_1', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_5', 'sensor_6',
#        'sensor_7', 'sensor_8', 'sensor_9', 'sensor_10', 'sensor_11',
#        'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15', 'sensor_16',
#        'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20', 'sensor_21'],
#       dtype='object')

# %%
scaler = MinMaxScaler()
X_train_s = pd.DataFrame( scaler.fit_transform(X_train), columns = X_train.columns )
X_valid_s = pd.DataFrame( scaler.fit_transform(X_valid), columns = X_valid.columns )
X_test_s = pd.DataFrame( scaler.fit_transform(X_test), columns = X_test.columns )

# %%
def evaluate(y_true, y_hat, label='test'):
  rmse = np.sqrt( mean_squared_error(y_true, y_hat) )
  variance = r2_score(y_true, y_hat)
  mae = mean_absolute_error(y_true, y_hat)
  print('{} set RMSE:{}, R2:{}, MAE:{}'.format(label, rmse, variance,mae))

#plot real data and the predicted one to make some comparison
def plot_predActual(y_test, y_predictions,model_name):
  plt.style.use('seaborn-white')
  plt.rcParams['figure.figsize']=20,5
  fig,ax = plt.subplots()
  plt.title( model_name +' prediction result',fontsize =16)
  plt.ylabel('RUL',fontsize =16)
  plt.xlabel('Test Engine Units',fontsize =16)
  g = sns.lineplot(x = np.arange(0,len(train['unit_number'].unique())),y = y_test,color='lightseagreen',label = 'actual',ax=ax)
  f = sns.lineplot(x = np.arange(0,len(train['unit_number'].unique())),y = y_predictions,color='salmon',label = 'predictions',ax=ax)
  ax.grid(True)
  ax.legend()
  plt.show()

# %%
model_svr = SVR()

# %%
models = {'SVR':model_svr}

# %%
for model_name, model in models.items():
  print("================",model_name,"================")
  model.fit(X_train_s,y_train)
  y_train_pred = model.predict(X_train_s) #Prediction on train data
  evaluate(y_train, y_train_pred, label='train')

  y_valid_pred = model.predict(X_valid_s) #Prediction on validation data
  evaluate(y_valid, y_valid_pred, label='valid')

  y_test_pred = model.predict(X_test_s)  #Prediction on test data
  evaluate(y_test, y_test_pred, label='test')
# Out:
# ================ SVR ================
# train set RMSE:82.07806715535051, R2:0.161856468171501, MAE:63.69577174121678
# valid set RMSE:82.39476212690415, R2:0.16334156111703801, MAE:64.12793592529101
# test set RMSE:48.98384918189362, R2:0.19288820423712616, MAE:40.227534100566864
