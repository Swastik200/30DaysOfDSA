# %% [markdown]
# <a href="https://colab.research.google.com/github/Swastik200/30DaysOfDSA/blob/main/PSO2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyMetaheuristic
# Out:
# Collecting pyMetaheuristic
#   Downloading pyMetaheuristic-1.9.5-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyMetaheuristic) (1.25.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from pyMetaheuristic) (5.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pyMetaheuristic) (1.11.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->pyMetaheuristic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly->pyMetaheuristic) (24.0)
# Installing collected packages: pyMetaheuristic
# Successfully installed pyMetaheuristic-1.9.5

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.linear_model import LinearRegression
from pyMetaheuristic.algorithm import particle_swarm_optimization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/CMAPSS.zip" "/content"
# !unzip CMAPSS.zip
# Out:
# Archive:  CMAPSS.zip
#   inflating: CMAPSS/readme.txt
#   inflating: CMAPSS/RUL_FD001.txt
#   inflating: CMAPSS/RUL_FD002.txt
#   inflating: CMAPSS/RUL_FD003.txt
#   inflating: CMAPSS/RUL_FD004.txt
#   inflating: CMAPSS/test_FD001.txt
#   inflating: CMAPSS/test_FD002.txt
#   inflating: CMAPSS/test_FD003.txt
#   inflating: CMAPSS/test_FD004.txt
#   inflating: CMAPSS/train_FD001.txt
#   inflating: CMAPSS/train_FD002.txt
#   inflating: CMAPSS/train_FD003.txt
#   inflating: CMAPSS/train_FD004.txt
#   inflating: CMAPSS/x.txt

# %%
index_names = ['unit_number', 'time_cycles']
setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names = ['sensor_{}'.format(i) for i in range(1,22)]
col_names = index_names + setting_names + sensor_names

# %%
path = '/content/CMAPSS/'
df_train = pd.read_csv(path + 'train_FD002.txt', sep='\s+', header=None)
df_test = pd.read_csv(path + 'test_FD002.txt', sep='\s+', header=None)
y_test = pd.read_csv(path + 'RUL_FD002.txt', sep='\s+', header=None)

# %%
train = df_train.copy()
test = df_test.copy()
display(train)
display(test)
# Out:
#         0    1        2       3      4       5       6        7        8   \
# 0        1    1  34.9983  0.8400  100.0  449.44  555.32  1358.61  1137.23
# 1        1    2  41.9982  0.8408  100.0  445.00  549.90  1353.22  1125.78
# 2        1    3  24.9988  0.6218   60.0  462.54  537.31  1256.76  1047.45
# 3        1    4  42.0077  0.8416  100.0  445.00  549.51  1354.03  1126.38
# 4        1    5  25.0005  0.6203   60.0  462.54  537.07  1257.71  1047.93
# ...    ...  ...      ...     ...    ...     ...     ...      ...      ...
# 53754  260  312  20.0037  0.7000  100.0  491.19  608.79  1495.60  1269.51
# 53755  260  313  10.0022  0.2510  100.0  489.05  605.81  1514.32  1324.12
# 53756  260  314  25.0041  0.6200   60.0  462.54  537.48  1276.24  1057.92
# 53757  260  315  25.0033  0.6220   60.0  462.54  537.84  1272.95  1066.30
# 53758  260  316  35.0036  0.8400  100.0  449.44  556.64  1374.61  1145.52
#
#           9   ...      16       17       18       19    20   21    22      23  \
# 0       5.48  ...  183.06  2387.72  8048.56   9.3461  0.02  334  2223  100.00
# 1       3.91  ...  130.42  2387.66  8072.30   9.3774  0.02  330  2212  100.00
# 2       7.05  ...  164.22  2028.03  7864.87  10.8941  0.02  309  1915   84.93
# 3       3.91  ...  130.72  2387.61  8068.66   9.3528  0.02  329  2212  100.00
# 4       7.05  ...  164.31  2028.00  7861.23  10.8963  0.02  309  1915   84.93
# ...      ...  ...     ...      ...      ...      ...   ...  ...   ...     ...
# 53754   9.35  ...  314.05  2389.02  8169.64   9.3035  0.03  369  2324  100.00
# 53755  10.52  ...  371.22  2388.42  8245.36   8.7586  0.03  374  2319  100.00
# 53756   7.05  ...  163.74  2030.33  7971.25  11.0657  0.02  310  1915   84.93
# 53757   7.05  ...  164.37  2030.35  7972.47  11.0537  0.02  311  1915   84.93
# 53758   5.48  ...  183.09  2390.38  8185.35   9.3998  0.02  338  2223  100.00
#
#           24       25
# 0      14.73   8.8071
# 1      10.41   6.2665
# 2      14.08   8.6723
# 3      10.59   6.4701
# 4      14.13   8.5286
# ...      ...      ...
# 53754  24.36  14.5189
# 53755  28.10  16.9454
# 53756  14.19   8.5503
# 53757  14.05   8.3729
# 53758  14.75   8.8446
#
# [53759 rows x 26 columns]
#         0    1        2       3      4       5       6        7        8   \
# 0        1    1   9.9987  0.2502  100.0  489.05  605.03  1497.17  1304.99
# 1        1    2  20.0026  0.7000  100.0  491.19  607.82  1481.20  1246.11
# 2        1    3  35.0045  0.8400  100.0  449.44  556.00  1359.08  1128.36
# 3        1    4  42.0066  0.8410  100.0  445.00  550.17  1349.69  1127.89
# 4        1    5  24.9985  0.6213   60.0  462.54  536.72  1253.18  1050.69
# ...    ...  ...      ...     ...    ...     ...     ...      ...      ...
# 33986  259  119  35.0015  0.8403  100.0  449.44  555.56  1366.01  1129.47
# 33987  259  120  42.0066  0.8405  100.0  445.00  549.42  1351.13  1123.86
# 33988  259  121  42.0061  0.8400  100.0  445.00  549.65  1349.14  1118.91
# 33989  259  122   0.0024  0.0003  100.0  518.67  642.58  1589.61  1408.16
# 33990  259  123  42.0033  0.8400  100.0  445.00  549.77  1342.50  1126.96
#
#           9   ...      16       17       18       19    20   21    22      23  \
# 0      10.52  ...  371.69  2388.18  8114.10   8.6476  0.03  369  2319  100.00
# 1       9.35  ...  315.32  2388.12  8053.06   9.2405  0.02  364  2324  100.00
# 2       5.48  ...  183.04  2387.75  8053.04   9.3472  0.02  333  2223  100.00
# 3       3.91  ...  130.40  2387.72  8066.90   9.3961  0.02  332  2212  100.00
# 4       7.05  ...  164.56  2028.05  7865.66  10.8682  0.02  305  1915   84.93
# ...      ...  ...     ...      ...      ...      ...   ...  ...   ...     ...
# 33986   5.48  ...  183.05  2388.39  8088.36   9.3215  0.02  334  2223  100.00
# 33987   3.91  ...  130.74  2388.31  8108.48   9.3542  0.02  332  2212  100.00
# 33988   3.91  ...  130.96  2388.34  8098.77   9.3836  0.02  331  2212  100.00
# 33989  14.62  ...  522.25  2388.00  8161.85   8.4279  0.03  393  2388  100.00
# 33990   3.91  ...  130.93  2388.40  8105.28   9.3458  0.02  331  2212  100.00
#
#           24       25
# 0      28.42  17.1551
# 1      24.29  14.8039
# 2      14.98   8.9125
# 3      10.35   6.4181
# 4      14.31   8.5740
# ...      ...      ...
# 33986  14.94   8.9065
# 33987  10.57   6.4075
# 33988  10.57   6.4805
# 33989  39.08  23.3589
# 33990  10.63   6.3480
#
# [33991 rows x 26 columns]

# %%
X_train = df_train.iloc[:, 5:]  # Adjust column index according to your dataset
y_train = df_train[0]  # Assuming RUL is the first column
X_test = df_test.iloc[:, 5:]  # Adjust column index according to your dataset
y_test = y_test[0]

# %%
def target_function(variables_values):
    model = LinearRegression()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    return rmse

# %%
parameters_pso = {
    'swarm_size': 250,
    'min_values': [-5] * len(X_train.columns),  # Adjust according to your feature space
    'max_values': [5] * len(X_train.columns),  # Adjust according to your feature space
    'iterations': 10,
    'decay': 0,
    'w': 0.9,
    'c1': 2,
    'c2': 2,
    'verbose': True,
    'start_init': None,
    'target_value': None
}

# %%
# Ensure the number of samples in X_train and y_train are consistent
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Define target function for optimization (RMSE) using X_train and y_train
def target_function(variables_values):
    model = LinearRegression()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    return rmse

# PSO - Algorithm using X_train and y_train
pso_result = particle_swarm_optimization(target_function=target_function, **parameters_pso)
# Out:
# Iteration =  0  f(x) =  74.54916109185434
# Iteration =  1  f(x) =  74.54916109185434
# Iteration =  2  f(x) =  74.54916109185434
# Iteration =  3  f(x) =  74.54916109185434
# Iteration =  4  f(x) =  74.54916109185434
# Iteration =  5  f(x) =  74.54916109185434
# Iteration =  6  f(x) =  74.54916109185434
# Iteration =  7  f(x) =  74.54916109185434
# Iteration =  8  f(x) =  74.54916109185434
# Iteration =  9  f(x) =  74.54916109185434
# Iteration =  10  f(x) =  74.54916109185434

# %%
optimized_model = LinearRegression().fit(X_test, y_test)

# %%
rmse_test = np.sqrt(mean_squared_error(y_test, optimized_model.predict(X_test)))
r2_test = r2_score(y_test, optimized_model.predict(X_test))
mae_test = mean_absolute_error(y_test, optimized_model.predict(X_test))

# %%
print('RMSE (Test):', rmse_test)
print('R2 Score (Test):', r2_test)
print('MAE (Test):', mae_test)
# Out:
# RMSE (Test): 74.46465988253499
# R2 Score (Test): 0.006563598685896732
# MAE (Test): 63.86467674465242
