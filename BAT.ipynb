# %% [markdown]
# <a href="https://colab.research.google.com/github/Swastik200/30DaysOfDSA/blob/main/BAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyMetaheuristic
# Out:
# Collecting pyMetaheuristic
#   Downloading pyMetaheuristic-1.9.5-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyMetaheuristic) (1.25.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from pyMetaheuristic) (5.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pyMetaheuristic) (1.11.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->pyMetaheuristic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly->pyMetaheuristic) (24.0)
# Installing collected packages: pyMetaheuristic
# Successfully installed pyMetaheuristic-1.9.5

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/CMAPSS.zip" "/content"
# !unzip CMAPSS.zip
# Out:
# Archive:  CMAPSS.zip
#   inflating: CMAPSS/readme.txt
#   inflating: CMAPSS/RUL_FD001.txt
#   inflating: CMAPSS/RUL_FD002.txt
#   inflating: CMAPSS/RUL_FD003.txt
#   inflating: CMAPSS/RUL_FD004.txt
#   inflating: CMAPSS/test_FD001.txt
#   inflating: CMAPSS/test_FD002.txt
#   inflating: CMAPSS/test_FD003.txt
#   inflating: CMAPSS/test_FD004.txt
#   inflating: CMAPSS/train_FD001.txt
#   inflating: CMAPSS/train_FD002.txt
#   inflating: CMAPSS/train_FD003.txt
#   inflating: CMAPSS/train_FD004.txt
#   inflating: CMAPSS/x.txt

# %%
index_names = ['unit_number', 'time_cycles']
setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names = ['sensor_{}'.format(i) for i in range(1,22)]
col_names = index_names + setting_names + sensor_names

# %%
path = '/content/CMAPSS/'
df_train = pd.read_csv(path+'train_FD001.txt',sep='\s+',header=None,index_col=False,names=col_names) #\s表示以空白為間隔
df_test = pd.read_csv(path+'test_FD001.txt',sep='\s+',header=None,index_col=False,names=col_names)
y_test = pd.read_csv(path+'RUL_FD001.txt',sep='\s+',header=None,index_col=False,names=['RUL'])
y_test.shape
# Out:
# (100, 1)

# %%
train = df_train.copy()
test = df_test.copy()
display(train)
display(test)
# Out:
#        unit_number  time_cycles  setting_1  setting_2  setting_3  sensor_1  \
# 0                1            1    -0.0007    -0.0004      100.0    518.67
# 1                1            2     0.0019    -0.0003      100.0    518.67
# 2                1            3    -0.0043     0.0003      100.0    518.67
# 3                1            4     0.0007     0.0000      100.0    518.67
# 4                1            5    -0.0019    -0.0002      100.0    518.67
# ...            ...          ...        ...        ...        ...       ...
# 20626          100          196    -0.0004    -0.0003      100.0    518.67
# 20627          100          197    -0.0016    -0.0005      100.0    518.67
# 20628          100          198     0.0004     0.0000      100.0    518.67
# 20629          100          199    -0.0011     0.0003      100.0    518.67
# 20630          100          200    -0.0032    -0.0005      100.0    518.67
#
#        sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  \
# 0        641.82   1589.70   1400.60     14.62  ...     521.66    2388.02
# 1        642.15   1591.82   1403.14     14.62  ...     522.28    2388.07
# 2        642.35   1587.99   1404.20     14.62  ...     522.42    2388.03
# 3        642.35   1582.79   1401.87     14.62  ...     522.86    2388.08
# 4        642.37   1582.85   1406.22     14.62  ...     522.19    2388.04
# ...         ...       ...       ...       ...  ...        ...        ...
# 20626    643.49   1597.98   1428.63     14.62  ...     519.49    2388.26
# 20627    643.54   1604.50   1433.58     14.62  ...     519.68    2388.22
# 20628    643.42   1602.46   1428.18     14.62  ...     520.01    2388.24
# 20629    643.23   1605.26   1426.53     14.62  ...     519.67    2388.23
# 20630    643.85   1600.38   1432.14     14.62  ...     519.30    2388.26
#
#        sensor_14  sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  \
# 0        8138.62     8.4195       0.03        392       2388      100.0
# 1        8131.49     8.4318       0.03        392       2388      100.0
# 2        8133.23     8.4178       0.03        390       2388      100.0
# 3        8133.83     8.3682       0.03        392       2388      100.0
# 4        8133.80     8.4294       0.03        393       2388      100.0
# ...          ...        ...        ...        ...        ...        ...
# 20626    8137.60     8.4956       0.03        397       2388      100.0
# 20627    8136.50     8.5139       0.03        395       2388      100.0
# 20628    8141.05     8.5646       0.03        398       2388      100.0
# 20629    8139.29     8.5389       0.03        395       2388      100.0
# 20630    8137.33     8.5036       0.03        396       2388      100.0
#
#        sensor_20  sensor_21
# 0          39.06    23.4190
# 1          39.00    23.4236
# 2          38.95    23.3442
# 3          38.88    23.3739
# 4          38.90    23.4044
# ...          ...        ...
# 20626      38.49    22.9735
# 20627      38.30    23.1594
# 20628      38.44    22.9333
# 20629      38.29    23.0640
# 20630      38.37    23.0522
#
# [20631 rows x 26 columns]
#        unit_number  time_cycles  setting_1  setting_2  setting_3  sensor_1  \
# 0                1            1     0.0023     0.0003      100.0    518.67
# 1                1            2    -0.0027    -0.0003      100.0    518.67
# 2                1            3     0.0003     0.0001      100.0    518.67
# 3                1            4     0.0042     0.0000      100.0    518.67
# 4                1            5     0.0014     0.0000      100.0    518.67
# ...            ...          ...        ...        ...        ...       ...
# 13091          100          194     0.0049     0.0000      100.0    518.67
# 13092          100          195    -0.0011    -0.0001      100.0    518.67
# 13093          100          196    -0.0006    -0.0003      100.0    518.67
# 13094          100          197    -0.0038     0.0001      100.0    518.67
# 13095          100          198     0.0013     0.0003      100.0    518.67
#
#        sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  \
# 0        643.02   1585.29   1398.21     14.62  ...     521.72    2388.03
# 1        641.71   1588.45   1395.42     14.62  ...     522.16    2388.06
# 2        642.46   1586.94   1401.34     14.62  ...     521.97    2388.03
# 3        642.44   1584.12   1406.42     14.62  ...     521.38    2388.05
# 4        642.51   1587.19   1401.92     14.62  ...     522.15    2388.03
# ...         ...       ...       ...       ...  ...        ...        ...
# 13091    643.24   1599.45   1415.79     14.62  ...     520.69    2388.00
# 13092    643.22   1595.69   1422.05     14.62  ...     521.05    2388.09
# 13093    643.44   1593.15   1406.82     14.62  ...     521.18    2388.04
# 13094    643.26   1594.99   1419.36     14.62  ...     521.33    2388.08
# 13095    642.95   1601.62   1424.99     14.62  ...     521.07    2388.05
#
#        sensor_14  sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  \
# 0        8125.55     8.4052       0.03        392       2388      100.0
# 1        8139.62     8.3803       0.03        393       2388      100.0
# 2        8130.10     8.4441       0.03        393       2388      100.0
# 3        8132.90     8.3917       0.03        391       2388      100.0
# 4        8129.54     8.4031       0.03        390       2388      100.0
# ...          ...        ...        ...        ...        ...        ...
# 13091    8213.28     8.4715       0.03        394       2388      100.0
# 13092    8210.85     8.4512       0.03        395       2388      100.0
# 13093    8217.24     8.4569       0.03        395       2388      100.0
# 13094    8220.48     8.4711       0.03        395       2388      100.0
# 13095    8214.64     8.4903       0.03        396       2388      100.0
#
#        sensor_20  sensor_21
# 0          38.86    23.3735
# 1          39.02    23.3916
# 2          39.08    23.4166
# 3          39.00    23.3737
# 4          38.99    23.4130
# ...          ...        ...
# 13091      38.65    23.1974
# 13092      38.57    23.2771
# 13093      38.62    23.2051
# 13094      38.66    23.2699
# 13095      38.70    23.1855
#
# [13096 rows x 26 columns]

# %%
def regression_model(X):
    # Define your regression model here
    model = LinearRegression()  # Example: Linear Regression
    model.fit(X_train, y_train)
    return model.predict(X)

# %%
# Calculate 'RUL' column based on 'time_cycles' and 'unit_number' columns
max_cycles = df_train.groupby('unit_number')['time_cycles'].max()
df_train['RUL'] = df_train.apply(lambda row: max_cycles[row['unit_number']] - row['time_cycles'], axis=1)

# %%
# Calculate 'RUL' column based on 'time_cycles' and 'unit_number' columns
max_cycles = df_test.groupby('unit_number')['time_cycles'].max()
df_test['RUL'] = df_test.apply(lambda row: max_cycles[row['unit_number']] - row['time_cycles'], axis=1)

# %%
X_train = df_train.drop(columns=['RUL'])
y_train = df_train['RUL']
X_test = df_test.drop(columns=['RUL'])
y_test = y_test['RUL']

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
def target_function(variables_values):
    # Train the regression model
    model = LinearRegression()
    model.fit(X_train_scaled, y_train)
    # Predict using the trained model
    predictions = model.predict(X_train_scaled)
    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y_train, predictions))
    return rmse

# %%
parameters = {
    'swarm_size': 25,
    'min_values': [0] * X_train_scaled.shape[1],  # Adjust according to your feature space
    'max_values': [1] * X_train_scaled.shape[1],  # Adjust according to your feature space
    'iterations': 100,
    'alpha': 0.8,
    'gama': 0.8,
    'fmin': 0,
    'fmax': 2,
    'verbose': True,
    'start_init': None,
    'target_value': None
}

# %%
from pyMetaheuristic.algorithm import bat_algorithm

# %%
bat_result = bat_algorithm(target_function=target_function, **parameters)
# Out:
# Iteration =  0  f(x) =  39.57671741181993
# Iteration =  1  f(x) =  39.57671741181993
# Iteration =  2  f(x) =  39.57671741181993
# Iteration =  3  f(x) =  39.57671741181993
# Iteration =  4  f(x) =  39.57671741181993
# Iteration =  5  f(x) =  39.57671741181993
# Iteration =  6  f(x) =  39.57671741181993
# Iteration =  7  f(x) =  39.57671741181993
# Iteration =  8  f(x) =  39.57671741181993
# Iteration =  9  f(x) =  39.57671741181993
# Iteration =  10  f(x) =  39.57671741181993
# Iteration =  11  f(x) =  39.57671741181993
# Iteration =  12  f(x) =  39.57671741181993
# Iteration =  13  f(x) =  39.57671741181993
# Iteration =  14  f(x) =  39.57671741181993
# Iteration =  15  f(x) =  39.57671741181993
# Iteration =  16  f(x) =  39.57671741181993
# Iteration =  17  f(x) =  39.57671741181993
# Iteration =  18  f(x) =  39.57671741181993
# Iteration =  19  f(x) =  39.57671741181993
# Iteration =  20  f(x) =  39.57671741181993
# Iteration =  21  f(x) =  39.57671741181993
# Iteration =  22  f(x) =  39.57671741181993
# Iteration =  23  f(x) =  39.57671741181993
# Iteration =  24  f(x) =  39.57671741181993
# Iteration =  25  f(x) =  39.57671741181993
# Iteration =  26  f(x) =  39.57671741181993
# Iteration =  27  f(x) =  39.57671741181993
# Iteration =  28  f(x) =  39.57671741181993
# Iteration =  29  f(x) =  39.57671741181993
# Iteration =  30  f(x) =  39.57671741181993
# Iteration =  31  f(x) =  39.57671741181993
# Iteration =  32  f(x) =  39.57671741181993
# Iteration =  33  f(x) =  39.57671741181993
# Iteration =  34  f(x) =  39.57671741181993
# Iteration =  35  f(x) =  39.57671741181993
# Iteration =  36  f(x) =  39.57671741181993
# Iteration =  37  f(x) =  39.57671741181993
# Iteration =  38  f(x) =  39.57671741181993
# Iteration =  39  f(x) =  39.57671741181993
# Iteration =  40  f(x) =  39.57671741181993
# Iteration =  41  f(x) =  39.57671741181993
# Iteration =  42  f(x) =  39.57671741181993
# Iteration =  43  f(x) =  39.57671741181993
# Iteration =  44  f(x) =  39.57671741181993
# Iteration =  45  f(x) =  39.57671741181993
# Iteration =  46  f(x) =  39.57671741181993
# Iteration =  47  f(x) =  39.57671741181993
# Iteration =  48  f(x) =  39.57671741181993
# Iteration =  49  f(x) =  39.57671741181993
# Iteration =  50  f(x) =  39.57671741181993
# Iteration =  51  f(x) =  39.57671741181993
# Iteration =  52  f(x) =  39.57671741181993
# Iteration =  53  f(x) =  39.57671741181993
# Iteration =  54  f(x) =  39.57671741181993
# Iteration =  55  f(x) =  39.57671741181993
# Iteration =  56  f(x) =  39.57671741181993
# Iteration =  57  f(x) =  39.57671741181993
# Iteration =  58  f(x) =  39.57671741181993
# Iteration =  59  f(x) =  39.57671741181993
# Iteration =  60  f(x) =  39.57671741181993
# Iteration =  61  f(x) =  39.57671741181993
# Iteration =  62  f(x) =  39.57671741181993
# Iteration =  63  f(x) =  39.57671741181993
# Iteration =  64  f(x) =  39.57671741181993
# Iteration =  65  f(x) =  39.57671741181993
# Iteration =  66  f(x) =  39.57671741181993
# Iteration =  67  f(x) =  39.57671741181993
# Iteration =  68  f(x) =  39.57671741181993
# Iteration =  69  f(x) =  39.57671741181993
# Iteration =  70  f(x) =  39.57671741181993
# Iteration =  71  f(x) =  39.57671741181993
# Iteration =  72  f(x) =  39.57671741181993
# Iteration =  73  f(x) =  39.57671741181993
# Iteration =  74  f(x) =  39.57671741181993
# Iteration =  75  f(x) =  39.57671741181993
# Iteration =  76  f(x) =  39.57671741181993
# Iteration =  77  f(x) =  39.57671741181993
# Iteration =  78  f(x) =  39.57671741181993
# Iteration =  79  f(x) =  39.57671741181993
# Iteration =  80  f(x) =  39.57671741181993
# Iteration =  81  f(x) =  39.57671741181993
# Iteration =  82  f(x) =  39.57671741181993
# Iteration =  83  f(x) =  39.57671741181993
# Iteration =  84  f(x) =  39.57671741181993
# Iteration =  85  f(x) =  39.57671741181993
# Iteration =  86  f(x) =  39.57671741181993
# Iteration =  87  f(x) =  39.57671741181993
# Iteration =  88  f(x) =  39.57671741181993
# Iteration =  89  f(x) =  39.57671741181993
# Iteration =  90  f(x) =  39.57671741181993
# Iteration =  91  f(x) =  39.57671741181993
# Iteration =  92  f(x) =  39.57671741181993
# Iteration =  93  f(x) =  39.57671741181993
# Iteration =  94  f(x) =  39.57671741181993
# Iteration =  95  f(x) =  39.57671741181993
# Iteration =  96  f(x) =  39.57671741181993
# Iteration =  97  f(x) =  39.57671741181993
# Iteration =  98  f(x) =  39.57671741181993
# Iteration =  99  f(x) =  39.57671741181993
# Iteration =  100  f(x) =  39.57671741181993

# %%
# Select the first 100 samples from X_test_scaled and their corresponding target values
X_test_scaled_subset = X_test_scaled[:100]
y_test_subset = y_test[:100]

# %%
optimized_model = LinearRegression().fit(X_test_scaled_subset, y_test_subset)

# %%
rmse_test = np.sqrt(mean_squared_error(y_test_subset, optimized_model.predict(X_test_scaled_subset)))
r2_test = r2_score(y_test_subset, optimized_model.predict(X_test_scaled_subset))
mae_test = mean_absolute_error(y_test_subset, optimized_model.predict(X_test_scaled_subset))

# %%
print('RMSE (Test):', rmse_test)
print('R2 Score (Test):', r2_test)
print('MAE (Test):', mae_test)
# Out:
# RMSE (Test): 38.34972118435803
# R2 Score (Test): 0.14834269193342697
# MAE (Test): 32.45180547125285
